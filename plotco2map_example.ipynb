# %%
# load the co2map object
from src.utils import Map
# the first argument is the path where the data is placed 
# the following 2 arguments specify the duration for visualization
co2map = Map( '2015-01-01', '2015-01-5')
# Out:
# query: SELECT * FROM CO2_SATELLITE.PUBLIC.CO2_SATELLITE2 WHERE ("time" between  '2015-01-01' and  '2015-01-5') and  ("longitude" between 139.3 and 140.4) and  ("latitude" between 35.15 and 36.05)
# 2429 queries are returned

# %%
# check that if the default upper and lower limit is appropriate or not
co2map.plot_fig_check_value_range()
# Out:
# fig/xcoc2-20150101_20150105-tokyo.png is generated.

# %%
co2map.plot_dotplot_fig(jump=20)
# Out:
# fig/xco2_point-20150101_20150105-tokyo.png is generated.

# %%
# change the default upper and lower limit of the co2 values for visualizing
co2map.set_co2_minmax(385, 410)
co2map.plot_fig_check_value_range()
# Out:
# chnage the visializing range from 385 to 410
# fig/xcoc2-20150101_20150105-tokyo.png is generated.

# %%
co2map.plot_dotplot_fig(jump=20)
# Out:
# fig/xco2_point-20150101_20150105-tokyo.png is generated.

# %%
co2map.plot_meshgridmap_fig()
# Out:
# /Users/hayashi/Documents/code/20221201_oco2_visual/oco2_visual/src/utils.py:395: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cax.set_yticklabels(['{0:.0f}'.format(x)  for x in np.linspace(self.xco2_min, self.xco2_max, len(cax_tick_label))])
# fig/xcoc2_map_meshgrid-20150101_20150105-2-tokyo.png is generated.

# %%
# add another map in other time window (with the identical fov, visualization value range )
co2map.add_map('2019-01-01', '2019-01-15')
# Out:
# query: SELECT * FROM CO2_SATELLITE.PUBLIC.CO2_SATELLITE2 WHERE ("time" between  '2019-01-01' and  '2019-01-15') and  ("longitude" between 139.3 and 140.4) and  ("latitude" between 35.15 and 36.05)
# 2424 queries are returned

# %%
co2map.plot_fig_check_value_range(mode_2panel=True)
# Out:
# fig/xcoc2-20150101_20150105-tokyo.png is generated.

# %%
co2map.set_co2_minmax(380, 420)
co2map.plot_fig_check_value_range(mode_2panel=True)
# Out:
# chnage the visializing range from 380 to 420
# fig/xcoc2-20150101_20150105-tokyo.png is generated.

# %%
co2map.plot_meshgridmap_2panel_fig()
# Out:
# /Users/hayashi/Documents/code/20221201_oco2_visual/oco2_visual/src/utils.py:544: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# fig/xcoc2_map_meshgrid-20150101_20150105-20190101_20150105-5.png is generated.

# %%
# create another map: taiwan
co2map2 = Map(
    '2015-02-01', 
    '2015-04-30', 
    fov_lon=[119, 122],
    fov_lat=[21, 27], 
    map_name='taiwan')
# Out:
# query: SELECT * FROM CO2_SATELLITE.PUBLIC.CO2_SATELLITE2 WHERE ("time" between  '2015-02-01' and  '2015-04-30') and  ("longitude" between 119 and 122) and  ("latitude" between 21 and 27)
# 1442 queries are returned

# %%
co2map2.plot_fig_check_value_range()
# Out:
# fig/xcoc2-20150201_20150430-taiwan.png is generated.

# %%
co2map2.plot_meshgridmap_fig()
# Out:
# /Users/hayashi/Documents/code/20221201_oco2_visual/oco2_visual/src/utils.py:395: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cax.set_yticklabels(['{0:.0f}'.format(x)  for x in np.linspace(self.xco2_min, self.xco2_max, len(cax_tick_label))])
# fig/xcoc2_map_meshgrid-20150201_20150430-2-taiwan.png is generated.
